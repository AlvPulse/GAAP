# %%
from beamformer.element_model import MeasuredVaractor
element =MeasuredVaractor()
print(element.v_max)
element= MeasuredVaractor(folding=False)
print(element.v_max)
